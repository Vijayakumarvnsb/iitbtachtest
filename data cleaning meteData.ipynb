# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\vijay\\Desktop\\data12\\movies_metadata.csv")
data.head(15)
# Out:
# c:\python39\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   False                                                NaN  65000000
# 2   False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   False                                                NaN  16000000
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5   False                                                NaN  60000000
# 6   False                                                NaN  58000000
# 7   False                                                NaN         0
# 8   False                                                NaN  35000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10  False                                                NaN  62000000
# 11  False                                                NaN         0
# 12  False  {'id': 117693, 'name': 'Balto Collection', 'po...         0
# 13  False                                                NaN  44000000
# 14  False                                                NaN  98000000
#
#                                                genres  \
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                      [{'id': 35, 'name': 'Comedy'}]
# 5   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 6   [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 7   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 9   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 10  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 11  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 12  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 13  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                         homepage     id    imdb_id  \
# 0           http://toystory.disney.com/toy-story    862  tt0114709
# 1                                            NaN   8844  tt0113497
# 2                                            NaN  15602  tt0113228
# 3                                            NaN  31357  tt0114885
# 4                                            NaN  11862  tt0113041
# 5                                            NaN    949  tt0113277
# 6                                            NaN  11860  tt0114319
# 7                                            NaN  45325  tt0112302
# 8                                            NaN   9091  tt0114576
# 9   http://www.mgm.com/view/movie/757/Goldeneye/    710  tt0113189
# 10                                           NaN   9087  tt0112346
# 11                                           NaN  12110  tt0112896
# 12                                           NaN  21032  tt0112453
# 13                                           NaN  10858  tt0113987
# 14                                           NaN   1408  tt0112760
#
#    original_language               original_title  \
# 0                 en                    Toy Story
# 1                 en                      Jumanji
# 2                 en             Grumpier Old Men
# 3                 en            Waiting to Exhale
# 4                 en  Father of the Bride Part II
# 5                 en                         Heat
# 6                 en                      Sabrina
# 7                 en                 Tom and Huck
# 8                 en                 Sudden Death
# 9                 en                    GoldenEye
# 10                en       The American President
# 11                en  Dracula: Dead and Loving It
# 12                en                        Balto
# 13                en                        Nixon
# 14                en             Cutthroat Island
#
#                                              overview  ... release_date  \
# 0   Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1   When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2   A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3   Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4   Just when George Banks has recovered from his ...  ...   1995-02-10
# 5   Obsessive master thief, Neil McCauley leads a ...  ...   1995-12-15
# 6   An ugly duckling having undergone a remarkable...  ...   1995-12-15
# 7   A mischievous young boy, Tom Sawyer, witnesses...  ...   1995-12-22
# 8   International action superstar Jean Claude Van...  ...   1995-12-22
# 9   James Bond must unmask the mysterious head of ...  ...   1995-11-16
# 10  Widowed U.S. president Andrew Shepherd, one of...  ...   1995-11-17
# 11  When a lawyer shows up at the vampire's doorst...  ...   1995-12-22
# 12  An outcast half-wolf risks his life to prevent...  ...   1995-12-22
# 13  An all-star cast powers this epic look at Amer...  ...   1995-12-22
# 14  Morgan Adams and her slave, William Shaw, are ...  ...   1995-12-22
#
#         revenue runtime                                   spoken_languages  \
# 0   373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1   262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2           0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3    81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4    76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 5   187436818.0   170.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 6           0.0   127.0  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
# 7           0.0    97.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 8    64350171.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 9   352194034.0   130.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 10  107879496.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 11          0.0    88.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 12   11348324.0    78.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 13   13681765.0   192.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 14   10017322.0   119.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#       status                                            tagline  \
# 0   Released                                                NaN
# 1   Released          Roll the dice and unleash the excitement!
# 2   Released  Still Yelling. Still Fighting. Still Ready for...
# 3   Released  Friends are the people who let you be yourself...
# 4   Released  Just When His World Is Back To Normal... He's ...
# 5   Released                           A Los Angeles Crime Saga
# 6   Released  You are cordially invited to the most surprisi...
# 7   Released                             The Original Bad Boys.
# 8   Released                         Terror goes into overtime.
# 9   Released               No limits. No fears. No substitutes.
# 10  Released  Why can't the most powerful man in the world h...
# 11  Released                                                NaN
# 12  Released                     Part Dog. Part Wolf. All Hero.
# 13  Released  Triumphant in Victory, Bitter in Defeat. He Ch...
# 14  Released  The Course Has Been Set. There Is No Turning B...
#
#                           title  video vote_average vote_count
# 0                     Toy Story  False          7.7     5415.0
# 1                       Jumanji  False          6.9     2413.0
# 2              Grumpier Old Men  False          6.5       92.0
# 3             Waiting to Exhale  False          6.1       34.0
# 4   Father of the Bride Part II  False          5.7      173.0
# 5                          Heat  False          7.7     1886.0
# 6                       Sabrina  False          6.2      141.0
# 7                  Tom and Huck  False          5.4       45.0
# 8                  Sudden Death  False          5.5      174.0
# 9                     GoldenEye  False          6.6     1194.0
# 10       The American President  False          6.5      199.0
# 11  Dracula: Dead and Loving It  False          5.7      210.0
# 12                        Balto  False          7.1      423.0
# 13                        Nixon  False          7.1       72.0
# 14             Cutthroat Island  False          5.7      137.0
#
# [15 rows x 24 columns]

# %%
data.shape
# Out:
# (45466, 24)

# %%
data.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# # adult

# %%
data.adult.unique()
# Out:
# array(['False', 'True', ' - Written by Ørnås',
#        ' Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.',
#        ' Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.'],
#       dtype=object)

# %%
data.loc[~data.adult.isin(['False','True']),:]
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...
#
#                                                 homepage          id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# 35587           [{'iso_3166_1': 'CA', 'name': 'Canada'}]  2014-01-01       0
#
#       original_language                            original_title  overview  \
# 19730             104.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 29503              68.0      [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 35587              82.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#        ... release_date revenue runtime spoken_languages status  tagline  \
# 19730  ...            1     NaN     NaN              NaN    NaN      NaN
# 29503  ...           12     NaN     NaN              NaN    NaN      NaN
# 35587  ...           22     NaN     NaN              NaN    NaN      NaN
#
#        title video vote_average vote_count
# 19730    NaN   NaN          NaN        NaN
# 29503    NaN   NaN          NaN        NaN
# 35587    NaN   NaN          NaN        NaN
#
# [3 rows x 24 columns]

# %%
data.adult.value_counts()
# Out:
# False                                                                                                                             45454
# True                                                                                                                                  9
#  Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.                        1
#  - Written by Ørnås                                                                                                                   1
#  Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.        1
# Name: adult, dtype: int64

# %%
data.adult.unique()
# Out:
# array(['False', 'True', ' - Written by Ørnås',
#        ' Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.',
#        ' Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.'],
#       dtype=object)

# %%
data.adult.unique()
data.adult.value_counts()


data = data.loc[data.adult.isin(['False','True']),:]
data.adult.unique()
data.shape
# Out:
# (45463, 24)

# %%
data.adult.value_counts()
# Out:
# False    45454
# True         9
# Name: adult, dtype: int64

# %%
data.adult = data.adult.map({'True':True,'False':False})
data.adult
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45461    False
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# Name: adult, Length: 45463, dtype: bool

# %%
data.loc[~data.adult.isin(['False','True']),:]
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview  ... release_date  \
# 0      Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1      When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2      A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3      Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4      Just when George Banks has recovered from his ...  ...   1995-02-10
# ...                                                  ...  ...          ...
# 45461        Rising and falling between a man and woman.  ...          NaN
# 45462  An artist struggles to finish his work while a...  ...   2011-11-17
# 45463  When one of her hits goes wrong, a professiona...  ...   2003-08-01
# 45464  In a small town live two brothers, one a minis...  ...   1917-10-21
# 45465  50 years after decriminalisation of homosexual...  ...   2017-06-09
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45461          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45463          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464          0.0    87.0                                                 []
# 45465          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45461  Released         Rising and falling between a man and woman
# 45462  Released                                                NaN
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45461                       Subdue  False          4.0        1.0
# 45462          Century of Birthing  False          9.0        3.0
# 45463                     Betrayal  False          3.8        6.0
# 45464             Satan Triumphant  False          0.0        0.0
# 45465                     Queerama  False          0.0        0.0
#
# [45463 rows x 24 columns]

# %%
data.adult.values[19730]
# Out:
# False

# %% [markdown]
# # belongs to collection

# %%
data.belongs_to_collection.values[0]
# Out:
# "{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}"

# %%
import ast
ast.literal_eval(data.belongs_to_collection.values[0])['id']
# Out:
# 10194

# %%
2 == 2
# Out:
# True

# %%
import numpy as np
np.nan == np.nan
# Out:
# False

# %%
import ast

collectionIds = []
for i in data['belongs_to_collection'].values:
    if i != i:
        collectionIds.append(-1)
        continue
    collectionIds.append(ast.literal_eval(i)['id'])

data['collectionId'] = collectionIds
data = data.drop(columns = ['belongs_to_collection'])

# %%
data
# Out:
#        adult    budget                                             genres  \
# 0      False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4      False         0                     [{'id': 35, 'name': 'Comedy'}]
# ...      ...       ...                                                ...
# 45461  False         0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462  False         0                      [{'id': 18, 'name': 'Drama'}]
# 45463  False         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464  False         0                                                 []
# 45465  False         0                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview popularity  ...  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943  ...
# 1      When siblings Judy and Peter discover an encha...  17.015539  ...
# 2      A family wedding reignites the ancient feud be...    11.7129  ...
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495  ...
# 4      Just when George Banks has recovered from his ...   8.387519  ...
# ...                                                  ...        ...  ...
# 45461        Rising and falling between a man and woman.   0.072051  ...
# 45462  An artist struggles to finish his work while a...   0.178241  ...
# 45463  When one of her hits goes wrong, a professiona...   0.903007  ...
# 45464  In a small town live two brothers, one a minis...   0.003503  ...
# 45465  50 years after decriminalisation of homosexual...   0.163015  ...
#
#            revenue runtime                                   spoken_languages  \
# 0      373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1      262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2              0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4       76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...            ...     ...                                                ...
# 45461          0.0    90.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462          0.0   360.0                  [{'iso_639_1': 'tl', 'name': ''}]
# 45463          0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464          0.0    87.0                                                 []
# 45465          0.0    75.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45461  Released         Rising and falling between a man and woman
# 45462  Released                                                NaN
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                              title  video vote_average vote_count collectionId
# 0                        Toy Story  False          7.7     5415.0        10194
# 1                          Jumanji  False          6.9     2413.0           -1
# 2                 Grumpier Old Men  False          6.5       92.0       119050
# 3                Waiting to Exhale  False          6.1       34.0           -1
# 4      Father of the Bride Part II  False          5.7      173.0        96871
# ...                            ...    ...          ...        ...          ...
# 45461                       Subdue  False          4.0        1.0           -1
# 45462          Century of Birthing  False          9.0        3.0           -1
# 45463                     Betrayal  False          3.8        6.0           -1
# 45464             Satan Triumphant  False          0.0        0.0           -1
# 45465                     Queerama  False          0.0        0.0           -1
#
# [45463 rows x 24 columns]

# %% [markdown]
# # data budget

# %%
data.budget.value_counts()
# Out:
# 0           36573
# 5000000       286
# 10000000      259
# 20000000      243
# 2000000       242
#             ...
# 4439832         1
# 421496          1
# 1073000         1
# 6965576         1
# 662141          1
# Name: budget, Length: 1223, dtype: int64

# %%
data.budget.describe()
# Out:
# count     45463
# unique     1223
# top           0
# freq      36573
# Name: budget, dtype: object

# %%
data.budget = data.budget.astype('int64')

# %%
data.dtypes
# Out:
# adult                      bool
# budget                    int64
# genres                   object
# homepage                 object
# id                       object
# imdb_id                  object
# original_language        object
# original_title           object
# overview                 object
# popularity               object
# poster_path              object
# production_companies     object
# production_countries     object
# release_date             object
# revenue                 float64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# video                    object
# vote_average            float64
# vote_count              float64
# collectionId              int64
# dtype: object

# %%
data.budget = data.budget.astype('int64')
data.budget.describe()
# Out:
# count    4.546300e+04
# mean     4.224579e+06
# std      1.742413e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      3.800000e+08
# Name: budget, dtype: float64

# %%
sum(data.budget == 0)*100/data.shape[0]
# Out:
# 80.44563711149726

# %% [markdown]
# # Genres

# %%
data.genres.values[0] #pandas -> string, list of dictionaries
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
import ast
index = 0
gen1 = []

for gen in data.genres.values:
  genList = ast.literal_eval(gen) ## converts string to list of dictionary
  if len(genList) > index: ##if the list has atleast one genre
    gen1.append(genList[0]['name']) #mark the id of the genre
  else:
    gen1.append('') #mark 0 as the id

data['genre1'] = gen1 #we have identified genre1

# %%
import ast
index = 1
gen2 = []

for gen in data.genres.values:
  genList = ast.literal_eval(gen) #converts string to list
  if len(genList) > index: # checks if the number of genres > 1
    gen2.append(genList[1]['name']) #takes the 2nd genre and appends to a list
  else:
    gen2.append('') #if the genre 2 is not present, append 0

data['genre2'] = gen2

# %%
import ast
index = 2
gen3 = []

for gen in data.genres.values:
  genList = ast.literal_eval(gen)
  if len(genList) > index:
    gen3.append(genList[2]['name'])
  else:
    gen3.append('')

data['genre3'] = gen3

# %%
import ast
index = 3
gen4 = []

for gen in data.genres.values:
  genList = ast.literal_eval(gen)
  if len(genList) > index:
    gen4.append(genList[3]['name'])
  else:
    gen4.append('')

data['genre4'] = gen4

# %%
sum(data.genre4 == '')*100/data.shape[0]
# Out:
# 90.32463819117582

# %%
data = data.drop(columns = ['genres'])

# %%
data
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview popularity  ...  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943  ...
# 1      When siblings Judy and Peter discover an encha...  17.015539  ...
# 2      A family wedding reignites the ancient feud be...    11.7129  ...
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495  ...
# 4      Just when George Banks has recovered from his ...   8.387519  ...
# ...                                                  ...        ...  ...
# 45461        Rising and falling between a man and woman.   0.072051  ...
# 45462  An artist struggles to finish his work while a...   0.178241  ...
# 45463  When one of her hits goes wrong, a professiona...   0.903007  ...
# 45464  In a small town live two brothers, one a minis...   0.003503  ...
# 45465  50 years after decriminalisation of homosexual...   0.163015  ...
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 45461  Released         Rising and falling between a man and woman
# 45462  Released                                                NaN
# 45463  Released                             A deadly game of wits.
# 45464  Released                                                NaN
# 45465  Released                                                NaN
#
#                              title  video  vote_average  vote_count  \
# 0                        Toy Story  False           7.7      5415.0
# 1                          Jumanji  False           6.9      2413.0
# 2                 Grumpier Old Men  False           6.5        92.0
# 3                Waiting to Exhale  False           6.1        34.0
# 4      Father of the Bride Part II  False           5.7       173.0
# ...                            ...    ...           ...         ...
# 45461                       Subdue  False           4.0         1.0
# 45462          Century of Birthing  False           9.0         3.0
# 45463                     Betrayal  False           3.8         6.0
# 45464             Satan Triumphant  False           0.0         0.0
# 45465                     Queerama  False           0.0         0.0
#
#           genre1   genre2    genre3 genre4
# 0      Animation   Comedy    Family
# 1      Adventure  Fantasy    Family
# 2        Romance   Comedy
# 3         Comedy    Drama   Romance
# 4         Comedy
# ...          ...      ...       ...    ...
# 45461      Drama   Family
# 45462      Drama
# 45463     Action    Drama  Thriller
# 45464
# 45465
#
# [45466 rows x 27 columns]

# %% [markdown]
# # homepage

# %%
data.homepage.isnull().sum()*100/data.shape[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-9df882d100f3> in <module>
# ----> 1 data.homepage.isnull().sum()*100/data.shape[0]
#
# c:\python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'homepage'

# %%
data['homePagePresent'] = (~data.homepage.isnull()) #fasle- if null in home page else true

# %%
data = data.drop(columns = ['homepage'])

# %%
data
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#            id    imdb_id original_language               original_title  \
# 0         862  tt0114709                en                    Toy Story
# 1        8844  tt0113497                en                      Jumanji
# 2       15602  tt0113228                en             Grumpier Old Men
# 3       31357  tt0114885                en            Waiting to Exhale
# 4       11862  tt0113041                en  Father of the Bride Part II
# ...       ...        ...               ...                          ...
# 45461  439050  tt6209470                fa                      رگ خواب
# 45462  111109  tt2028550                tl          Siglo ng Pagluluwal
# 45463   67758  tt0303758                en                     Betrayal
# 45464  227506  tt0008536                en          Satana likuyushchiy
# 45465  461257  tt6980792                en                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45461        Rising and falling between a man and woman.   0.072051
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path  ...  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...
# ...                                 ...  ...
# 45461  /jldsYflnId4tTWPx8es3uzsB1I8.jpg  ...
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg  ...
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg  ...
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg  ...
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg  ...
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  video  vote_average  vote_count  \
# 0                        Toy Story  False           7.7      5415.0
# 1                          Jumanji  False           6.9      2413.0
# 2                 Grumpier Old Men  False           6.5        92.0
# 3                Waiting to Exhale  False           6.1        34.0
# 4      Father of the Bride Part II  False           5.7       173.0
# ...                            ...    ...           ...         ...
# 45461                       Subdue  False           4.0         1.0
# 45462          Century of Birthing  False           9.0         3.0
# 45463                     Betrayal  False           3.8         6.0
# 45464             Satan Triumphant  False           0.0         0.0
# 45465                     Queerama  False           0.0         0.0
#
#           genre1   genre2    genre3 genre4 homePagePresent
# 0      Animation   Comedy    Family                   True
# 1      Adventure  Fantasy    Family                  False
# 2        Romance   Comedy                            False
# 3         Comedy    Drama   Romance                  False
# 4         Comedy                                     False
# ...          ...      ...       ...    ...             ...
# 45461      Drama   Family                             True
# 45462      Drama                                     False
# 45463     Action    Drama  Thriller                  False
# 45464                                                False
# 45465                                                False
#
# [45466 rows x 27 columns]

# %% [markdown]
# id

# %%
(data.shape[0] - len(data.id.unique()))
data = data.drop_duplicates(subset = 'id')

# %%
data.id.unique
# Out:
# <bound method Series.unique of 0           862
# 1          8844
# 2         15602
# 3         31357
# 4         11862
#           ...
# 45461    439050
# 45462    111109
# 45463     67758
# 45464    227506
# 45465    461257
# Name: id, Length: 45436, dtype: object>

# %%
data.imdb_id.values[0]
(data.shape[0] - len(data.imdb_id.unique()))
data = data.drop_duplicates(subset = 'imdb_id')

# %%
data.imdb_id.unique
# Out:
# <bound method Series.unique of 0        tt0114709
# 1        tt0113497
# 2        tt0113228
# 3        tt0114885
# 4        tt0113041
#            ...
# 45461    tt6209470
# 45462    tt2028550
# 45463    tt0303758
# 45464    tt0008536
# 45465    tt6980792
# Name: imdb_id, Length: 45418, dtype: object>

# %% [markdown]
# # orginal values

# %%
len(data.original_language.unique())
# Out:
# 91

# %%
len(data.original_language.unique())
data.original_language.isnull().sum()
data.loc[data.original_language.isnull(),:]
data = data.dropna(subset = ['original_language'])

# %%
data.original_language.isnull().sum()
# Out:
# 0

# %%
data.loc[data.original_language.isnull(),:]
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count, genre1, genre2, genre3, genre4, homePagePresent]
# Index: []
#
# [0 rows x 27 columns]

# %%
len(data.original_language.unique())
data.original_language.isnull().sum()
data.loc[data.original_language.isnull(),:]
data = data.dropna(subset = ['original_language'])

# %%
data
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#            id    imdb_id original_language               original_title  \
# 0         862  tt0114709                en                    Toy Story
# 1        8844  tt0113497                en                      Jumanji
# 2       15602  tt0113228                en             Grumpier Old Men
# 3       31357  tt0114885                en            Waiting to Exhale
# 4       11862  tt0113041                en  Father of the Bride Part II
# ...       ...        ...               ...                          ...
# 45461  439050  tt6209470                fa                      رگ خواب
# 45462  111109  tt2028550                tl          Siglo ng Pagluluwal
# 45463   67758  tt0303758                en                     Betrayal
# 45464  227506  tt0008536                en          Satana likuyushchiy
# 45465  461257  tt6980792                en                     Queerama
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45461        Rising and falling between a man and woman.   0.072051
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path  ...  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...
# ...                                 ...  ...
# 45461  /jldsYflnId4tTWPx8es3uzsB1I8.jpg  ...
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg  ...
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg  ...
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg  ...
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg  ...
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  video  vote_average  vote_count  \
# 0                        Toy Story  False           7.7      5415.0
# 1                          Jumanji  False           6.9      2413.0
# 2                 Grumpier Old Men  False           6.5        92.0
# 3                Waiting to Exhale  False           6.1        34.0
# 4      Father of the Bride Part II  False           5.7       173.0
# ...                            ...    ...           ...         ...
# 45461                       Subdue  False           4.0         1.0
# 45462          Century of Birthing  False           9.0         3.0
# 45463                     Betrayal  False           3.8         6.0
# 45464             Satan Triumphant  False           0.0         0.0
# 45465                     Queerama  False           0.0         0.0
#
#           genre1   genre2    genre3 genre4 homePagePresent
# 0      Animation   Comedy    Family                   True
# 1      Adventure  Fantasy    Family                  False
# 2        Romance   Comedy                            False
# 3         Comedy    Drama   Romance                  False
# 4         Comedy                                     False
# ...          ...      ...       ...    ...             ...
# 45461      Drama   Family                             True
# 45462      Drama                                     False
# 45463     Action    Drama  Thriller                  False
# 45464                                                False
# 45465                                                False
#
# [45407 rows x 27 columns]

# %% [markdown]
# # title

# %%
data.title.isnull().sum(), len(data.title.unique())*100/data.shape[0]
# Out:
# (4, 93.05613671900808)

# %%
data.original_title.isnull().sum(), len(data.original_title.unique())*100/data.shape[0]
# Out:
# (0, 95.46325456427424)

# %%
data = data.drop(columns = ['title'])

# %%
data.original_title = data['original_title'].str.lower()
data.original_title = data['original_title'].str.strip()

# %%
data.original_title
# Out:
# 0                          toy story
# 1                            jumanji
# 2                   grumpier old men
# 3                  waiting to exhale
# 4        father of the bride part ii
#                     ...
# 45461                        رگ خواب
# 45462            siglo ng pagluluwal
# 45463                       betrayal
# 45464            satana likuyushchiy
# 45465                       queerama
# Name: original_title, Length: 45407, dtype: object

# %% [markdown]
# # overview == lower and upper and remove unwanted space

# %%
data.overview = data.overview.str.lower()
data.overview = data.overview.str.strip()
data.overview
# Out:
# 0        led by woody, andy's toys live happily in his ...
# 1        when siblings judy and peter discover an encha...
# 2        a family wedding reignites the ancient feud be...
# 3        cheated on, mistreated and stepped on, the wom...
# 4        just when george banks has recovered from his ...
#                                ...
# 45461          rising and falling between a man and woman.
# 45462    an artist struggles to finish his work while a...
# 45463    when one of her hits goes wrong, a professiona...
# 45464    in a small town live two brothers, one a minis...
# 45465    50 years after decriminalisation of homosexual...
# Name: overview, Length: 45407, dtype: object

# %% [markdown]
# # data popularity

# %%
data.popularity
# Out:
# 0        21.946943
# 1        17.015539
# 2          11.7129
# 3         3.859495
# 4         8.387519
#            ...
# 45461     0.072051
# 45462     0.178241
# 45463     0.903007
# 45464     0.003503
# 45465     0.163015
# Name: popularity, Length: 45407, dtype: object

# %%
data.popularity.dtypes
# Out:
# dtype('O')

# %%
data.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# video                     object
# vote_average             float64
# vote_count               float64
# genre1                    object
# genre2                    object
# genre3                    object
# genre4                    object
# homePagePresent             bool
# dtype: object

# %%
data.popularity = data.popularity.astype('float64') ##floating point value
data.popularity.describe()
#data.popularity.quantile(0.999)
#sum(data.popularity > 100)
# Out:
# count    45403.000000
# mean         2.922572
# std          6.008171
# min          0.000000
# 25%          0.386396
# 50%          1.128080
# 75%          3.680236
# max        547.488298
# Name: popularity, dtype: float64

# %%
##outlier detection - 1) domain knowledge 2) u need to handle them
data.popularity = data.popularity.clip(0,50)
#data = data.loc[(data.popularity > 0) & (data.popularity <= 100),:]

# %% [markdown]
# # vote count vote average

# %%
data.vote_count.describe()
# Out:
# count    45403.000000
# mean       109.997643
# std        491.605860
# min          0.000000
# 25%          3.000000
# 50%         10.000000
# 75%         34.000000
# max      14075.000000
# Name: vote_count, dtype: float64

# %%
data.vote_count.isna().sum()
# Out:
# 4

# %%
data = data.loc[~data.vote_count.isna(),:]

# %%
data.vote_count.value_counts()
# Out:
# 1.0       3259
# 2.0       3129
# 0.0       2885
# 3.0       2780
# 4.0       2479
#           ...
# 838.0        1
# 1432.0       1
# 1825.0       1
# 4110.0       1
# 992.0        1
# Name: vote_count, Length: 1820, dtype: int64

# %%
data.vote_average.isna().sum()
# Out:
# 0

# %%
data.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# video                     object
# vote_average             float64
# vote_count               float64
# genre1                    object
# genre2                    object
# genre3                    object
# genre4                    object
# homePagePresent             bool
# dtype: object

# %%
data.vote_average = data.vote_average.astype('float64')
data.vote_count = data.vote_count.astype('int64')

# %%
data.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# video                     object
# vote_average             float64
# vote_count                 int64
# genre1                    object
# genre2                    object
# genre3                    object
# genre4                    object
# homePagePresent             bool
# dtype: object

# %%
data.vote_average.describe()
# Out:
# count    45403.000000
# mean         5.619461
# std          1.922518
# min          0.000000
# 25%          5.000000
# 50%          6.000000
# 75%          6.800000
# max         10.000000
# Name: vote_average, dtype: float64

# %%
data.vote_count.describe()
# Out:
# count    45403.000000
# mean       109.997643
# std        491.605860
# min          0.000000
# 25%          3.000000
# 50%         10.000000
# 75%         34.000000
# max      14075.000000
# Name: vote_count, dtype: float64

# %% [markdown]
# # poster path

# %%
data.poster_path.values #null value, unique values, file exists in the path or not
# Out:
# array(['/rhIRbceoE9lR4veEXuwCC2wARtG.jpg',
#        '/vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg',
#        '/6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg', ...,
#        '/d5bX92nDsISNhu3ZT69uHwmfCGw.jpg',
#        '/aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg',
#        '/s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg'], dtype=object)

# %%
data.poster_path.isnull().sum()
# Out:
# 378

# %%
import os
os.path.isfile('/rhIRbceoE9lR4veEXuwCC2wARtG.jpg')
# Out:
# False

# %%
data = data.drop(columns = ['poster_path'])

# %% [markdown]
# # production companies

# %%
data.production_companies.values[0]
# Out:
# "[{'name': 'Pixar Animation Studios', 'id': 3}]"

# %%
import ast
index = 0
prod1 = []

for prod in data.production_companies.values:
  prodList = ast.literal_eval(prod)
  if len(genList) > index:
    prod1.append(prodList[index]['name'])
  else:
    prod1.append('')

data['Producer1'] = prod1

# %%
import ast
index = 1
prod2 = []

for prod in data.production_companies.values:
  prodList = ast.literal_eval(prod)
  if len(genList) > index:
    prod2.append(prodList[index]['name'])
  else:
    prod2.append('')

data['Producer2'] = prod2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-159-8fb7e9dce91a> in <module>
#       3 prod2 = []
#       4
# ----> 5 for prod in data.production_companies.values:
#       6   prodList = ast.literal_eval(prod)
#       7   if len(genList) > index:
#
# c:\python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'production_companies'

# %%
data.head()
# Out:
#    adult                              belongs_to_collection    budget     id  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000    862
# 1  False                                                NaN  65000000   8844
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0  15602
# 3  False                                                NaN  16000000  31357
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0  11862
#
#      imdb_id original_language               original_title  \
# 0  tt0114709                en                    toy story
# 1  tt0113497                en                      jumanji
# 2  tt0113228                en             grumpier old men
# 3  tt0114885                en            waiting to exhale
# 4  tt0113041                en  father of the bride part ii
#
#                                             overview  popularity  \
# 0  led by woody, andy's toys live happily in his ...   21.946943
# 1  when siblings judy and peter discover an encha...   17.015539
# 2  a family wedding reignites the ancient feud be...   11.712900
# 3  cheated on, mistreated and stepped on, the wom...    3.859495
# 4  just when george banks has recovered from his ...    8.387519
#
#                                 production_countries  ...  video  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  False
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  False
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  False
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  False
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  False
#
#    vote_average  vote_count     genre1   genre2   genre3 genre4  \
# 0           7.7        5415  Animation   Comedy   Family
# 1           6.9        2413  Adventure  Fantasy   Family
# 2           6.5          92    Romance   Comedy
# 3           6.1          34     Comedy    Drama  Romance
# 4           5.7         173     Comedy
#
#    homePagePresent  Producer1 Producer2
# 0             True
# 1            False
# 2            False
# 3            False
# 4            False
#
# [5 rows x 26 columns]

# %%
data.release_date.values[0]
# Out:
# '1995-10-30'

# %%
data.release_date.isnull().sum()
# Out:
# 81

# %%
data.release_date
# Out:
# 0        1995-10-30
# 1        1995-12-15
# 2        1995-12-22
# 3        1995-12-22
# 4        1995-02-10
#             ...
# 45461           NaN
# 45462    2011-11-17
# 45463    2003-08-01
# 45464    1917-10-21
# 45465    2017-06-09
# Name: release_date, Length: 45403, dtype: object

# %%
data.loc[data.release_date.isnull(),:]
# Out:
#        adult belongs_to_collection budget      id    imdb_id  \
# 711    False                   NaN      0  365371  tt0114894
# 734    False                   NaN      0  215107  tt0105737
# 3460   False                   NaN      0   94214  tt0210130
# 3628   False                   NaN      0  207731  tt0217287
# 5879   False                   NaN      0   99885  tt0979876
# ...      ...                   ...    ...     ...        ...
# 45148  False                   NaN      0  438910  tt0810384
# 45203  False                   NaN      0  433711  tt3158690
# 45338  False                   NaN      0  335251  tt1883368
# 45410  False                   NaN      0  449131  tt0321264
# 45461  False                   NaN      0  439050  tt6209470
#
#       original_language                                  original_title  \
# 711                  en            war stories our mother never told us
# 734                  en                           vermont is for lovers
# 3460                 en                      jails, hospitals & hip-hop
# 3628                 en                                  boricua's bond
# 5879                 en                             divine intervention
# ...                 ...                                             ...
# 45148                ru               konstruktor krasnogo tsveta -1993
# 45203                en  all superheroes must die 2: the last superhero
# 45338                en                  the land where the blues began
# 45410                ru                                           aprel
# 45461                fa                                         رگ خواب
#
#                                                 overview  popularity  \
# 711    seven new zealand women speak about their live...    0.005625
# 734    vermont is for lovers is an independently prod...    0.750000
# 3460   jails, hospitals &amp; hip-hop is a cinematic ...    0.009057
# 3628   tommy, a talented puerto rican painter living ...    0.035352
# 5879   four friends fight an insane man's crusade to ...    0.001181
# ...                                                  ...         ...
# 45148  engineering red - 1993  dir: andrey i. y. petr...    0.001586
# 45203  in a no holds barred documentary, acclaimed jo...    0.000220
# 45338  an exploration of the musical and social origi...    0.000000
# 45410                                                NaN    0.008903
# 45461        rising and falling between a man and woman.    0.072051
#
#                            production_countries  ...  video  vote_average  \
# 711                                          []  ...  False           0.0
# 734                                          []  ...  False           0.0
# 3460                                         []  ...  False           0.0
# 3628                                         []  ...  False           2.0
# 5879                                         []  ...  False           0.0
# ...                                         ...  ...    ...           ...
# 45148                                        []  ...  False           6.0
# 45203                                        []  ...  False           4.0
# 45338                                        []  ...  False           0.0
# 45410  [{'iso_3166_1': 'RU', 'name': 'Russia'}]  ...  False           6.0
# 45461    [{'iso_3166_1': 'IR', 'name': 'Iran'}]  ...  False           4.0
#
#        vote_count   genre1           genre2   genre3 genre4  homePagePresent  \
# 711             0                                                      False
# 734             0                                                      False
# 3460            0    Drama                                             False
# 3628            1                                                      False
# 5879            0    Drama          Romance  Foreign                   False
# ...           ...      ...              ...      ...    ...              ...
# 45148           2                                                      False
# 45203           1  Mystery  Science Fiction                            False
# 45338           0                                                      False
# 45410           1    Drama            Crime                            False
# 45461           1    Drama           Family                             True
#
#        Producer1 Producer2
# 711
# 734
# 3460
# 3628
# 5879
# ...          ...       ...
# 45148
# 45203
# 45338
# 45410
# 45461
#
# [81 rows x 26 columns]

# %%
import datetime
dateString = '17-07-2021'
date = datetime.datetime.strptime(dateString, "%d-%m-%Y") #string to datetime
date + datetime.timedelta(days = 15)
#date.strftime("%d-%b-%Y") #datetime -> string
# Out:
# datetime.datetime(2021, 8, 1, 0, 0)

# %%
data.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# production_countries      object
# release_date              object
# revenue                    int64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# video                     object
# vote_average             float64
# vote_count                 int64
# genre1                    object
# genre2                    object
# genre3                    object
# genre4                    object
# homePagePresent             bool
# Producer1                 object
# Producer2                 object
# dtype: object

# %% [markdown]
# # revenues

# %%
data.revenue = data.revenue.astype('int64')

# %%
data.revenue.describe()
# Out:
# count    4.540300e+04
# mean     1.121955e+07
# std      6.437068e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.787965e+09
# Name: revenue, dtype: float64

# %%
sum(data.revenue == 0)*100/data.shape[0]
# Out:
# 83.7059225161333

# %% [markdown]
# # runtime

# %%
data.runtime = data.runtime.astype('float64')
data.runtime.describe()
# Out:
# count    45148.000000
# mean        94.141845
# std         38.402492
# min          0.000000
# 25%         85.000000
# 50%         95.000000
# 75%        107.000000
# max       1256.000000
# Name: runtime, dtype: float64

# %%
data.loc[data.runtime > 300,:]
# Out:
#        adult                              belongs_to_collection     budget  \
# 6747   False                                                NaN          0
# 7415   False                                                NaN          0
# 7420   False                                                NaN          0
# 7933   False  {'id': 138163, 'name': 'Trylogia Sienkiewicza'...          0
# 8635   False                                                NaN  100000000
# ...      ...                                                ...        ...
# 44176  False                                                NaN          0
# 44464  False                                                NaN          0
# 44721  False                                                NaN          0
# 44758  False                                                NaN          0
# 45462  False                                                NaN          0
#
#            id    imdb_id original_language             original_title  \
# 6747    42044  tt0090015                en                      shoah
# 7415   140207  tt0080297                en  tinker tailor soldier spy
# 7420    11659  tt0346336                it         la meglio gioventú
# 7933    36627  tt0072021                pl                      potop
# 8635    29266  tt0063794                ru                война и мир
# ...       ...        ...               ...                        ...
# 44176  444623  tt0366028                ru                      idiot
# 44464  197854  tt0143353                ja                   強殖装甲ガイバー
# 44721  458298  tt6792200                en                the keepers
# 44758  128733  tt0080230                en                  hollywood
# 45462  111109  tt2028550                tl        siglo ng pagluluwal
#
#                                                 overview  popularity  \
# 6747   claude lanzmann directed this 9 1/2 hour docum...    1.978031
# 7415   in the bleak days of the cold war, espionage v...    1.564586
# 7420   spanning four decades, from the chaotic 1960s ...    6.040001
# 7933   following with fire and sword', this is an ada...    0.868637
# 8635   seven-hour epic based on the eponymous book by...    2.604571
# ...                                                  ...         ...
# 44176             tv miniseries of the dostoevsky novel.    0.074146
# 44464  sho and his friend tetsurou stumble upon an od...    0.025827
# 44721  a seven-part docuseries about the unsolved mur...    1.576170
# 44758  the definitive documentary about the american ...    0.055713
# 45462  an artist struggles to finish his work while a...    0.178241
#
#                                     production_countries  ...  video  \
# 6747            [{'iso_3166_1': 'FR', 'name': 'France'}]  ...  False
# 7415    [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]  ...  False
# 7420             [{'iso_3166_1': 'IT', 'name': 'Italy'}]  ...  False
# 7933            [{'iso_3166_1': 'PL', 'name': 'Poland'}]  ...  False
# 8635            [{'iso_3166_1': 'RU', 'name': 'Russia'}]  ...  False
# ...                                                  ...  ...    ...
# 44176                                                 []  ...  False
# 44464            [{'iso_3166_1': 'JP', 'name': 'Japan'}]  ...  False
# 44721  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  False
# 44758                                                 []  ...  False
# 45462      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]  ...  False
#
#        vote_average  vote_count           genre1       genre2   genre3  \
# 6747            8.7          36      Documentary
# 7415            7.6          10         Thriller        Drama  Mystery
# 7420            8.0          88            Drama
# 7933            7.4           7          History    Adventure      War
# 8635            7.5          16              War        Drama  History
# ...             ...         ...              ...          ...      ...
# 44176           7.0           1         TV Movie
# 44464           6.2           5  Science Fiction    Animation  Foreign
# 44721           7.9          16            Crime  Documentary    Drama
# 44758           8.0           1
# 45462           9.0           3            Drama
#
#         genre4  homePagePresent  Producer1 Producer2
# 6747                      False
# 7415                      False
# 7420                      False
# 7933                      False
# 8635   Romance            False
# ...        ...              ...        ...       ...
# 44176                     False
# 44464   Action            False
# 44721                      True
# 44758                     False
# 45462                     False
#
# [108 rows x 26 columns]

# %% [markdown]
# # spoken languages

# %%
data.spoken_languages
# Out:
# 0                 [{'iso_639_1': 'en', 'name': 'English'}]
# 1        [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2                 [{'iso_639_1': 'en', 'name': 'English'}]
# 3                 [{'iso_639_1': 'en', 'name': 'English'}]
# 4                 [{'iso_639_1': 'en', 'name': 'English'}]
#                                ...
# 45461               [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462                    [{'iso_639_1': 'tl', 'name': ''}]
# 45463             [{'iso_639_1': 'en', 'name': 'English'}]
# 45464                                                   []
# 45465             [{'iso_639_1': 'en', 'name': 'English'}]
# Name: spoken_languages, Length: 45403, dtype: object

# %%
import ast
totalLanguages = []

for prod in data.spoken_languages.values:
  prodList = ast.literal_eval(prod) #converting from string to list of dictionary 
  totalLanguages.append(len(prodList)) #how many languages spoken?

data['TotalLanguages'] = totalLanguages

# %%
data.spoken_languages
# Out:
# 0                 [{'iso_639_1': 'en', 'name': 'English'}]
# 1        [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2                 [{'iso_639_1': 'en', 'name': 'English'}]
# 3                 [{'iso_639_1': 'en', 'name': 'English'}]
# 4                 [{'iso_639_1': 'en', 'name': 'English'}]
#                                ...
# 45461               [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462                    [{'iso_639_1': 'tl', 'name': ''}]
# 45463             [{'iso_639_1': 'en', 'name': 'English'}]
# 45464                                                   []
# 45465             [{'iso_639_1': 'en', 'name': 'English'}]
# Name: spoken_languages, Length: 45403, dtype: object

# %% [markdown]
# # status

# %%
data.status.value_counts()
# Out:
# Released           44961
# Rumored              226
# Post Production       98
# In Production         20
# Planned               15
# Canceled               2
# Name: status, dtype: int64

# %%
data.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'id', 'imdb_id',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'video', 'vote_average',
#        'vote_count', 'genre1', 'genre2', 'genre3', 'genre4', 'homePagePresent',
#        'Producer1', 'Producer2', 'TotalLanguages'],
#       dtype='object')

# %% [markdown]
# others

# %%
data.tagline.isnull().sum()
# Out:
# 25005

# %%
data.video.value_counts()
# Out:
# False    45310
# True        93
# Name: video, dtype: int64

# %%
data = data.drop(columns = ['tagline','video'])

# %%
data.head()
# Out:
#    adult                              belongs_to_collection    budget     id  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000    862
# 1  False                                                NaN  65000000   8844
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0  15602
# 3  False                                                NaN  16000000  31357
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0  11862
#
#      imdb_id original_language               original_title  \
# 0  tt0114709                en                    toy story
# 1  tt0113497                en                      jumanji
# 2  tt0113228                en             grumpier old men
# 3  tt0114885                en            waiting to exhale
# 4  tt0113041                en  father of the bride part ii
#
#                                             overview  popularity  \
# 0  led by woody, andy's toys live happily in his ...   21.946943
# 1  when siblings judy and peter discover an encha...   17.015539
# 2  a family wedding reignites the ancient feud be...   11.712900
# 3  cheated on, mistreated and stepped on, the wom...    3.859495
# 4  just when george banks has recovered from his ...    8.387519
#
#                                 production_countries  ... vote_average  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...  ...          7.7
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...  ...          6.9
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...  ...          6.5
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...  ...          6.1
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...  ...          5.7
#
#    vote_count     genre1   genre2   genre3  genre4  homePagePresent Producer1  \
# 0        5415  Animation   Comedy   Family                     True
# 1        2413  Adventure  Fantasy   Family                    False
# 2          92    Romance   Comedy                             False
# 3          34     Comedy    Drama  Romance                    False
# 4         173     Comedy                                      False
#
#   Producer2 TotalLanguages
# 0                        1
# 1                        2
# 2                        1
# 3                        1
# 4                        1
#
# [5 rows x 25 columns]

# %% [markdown]
# # final data

# %%
data
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#            id    imdb_id original_language               original_title  \
# 0         862  tt0114709                en                    toy story
# 1        8844  tt0113497                en                      jumanji
# 2       15602  tt0113228                en             grumpier old men
# 3       31357  tt0114885                en            waiting to exhale
# 4       11862  tt0113041                en  father of the bride part ii
# ...       ...        ...               ...                          ...
# 45461  439050  tt6209470                fa                      رگ خواب
# 45462  111109  tt2028550                tl          siglo ng pagluluwal
# 45463   67758  tt0303758                en                     betrayal
# 45464  227506  tt0008536                en          satana likuyushchiy
# 45465  461257  tt6980792                en                     queerama
#
#                                                 overview  popularity  \
# 0      led by woody, andy's toys live happily in his ...   21.946943
# 1      when siblings judy and peter discover an encha...   17.015539
# 2      a family wedding reignites the ancient feud be...   11.712900
# 3      cheated on, mistreated and stepped on, the wom...    3.859495
# 4      just when george banks has recovered from his ...    8.387519
# ...                                                  ...         ...
# 45461        rising and falling between a man and woman.    0.072051
# 45462  an artist struggles to finish his work while a...    0.178241
# 45463  when one of her hits goes wrong, a professiona...    0.903007
# 45464  in a small town live two brothers, one a minis...    0.003503
# 45465  50 years after decriminalisation of homosexual...    0.163015
#
#                                     production_countries  ... vote_average  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...  ...          7.7
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...  ...          6.9
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...  ...          6.5
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...  ...          6.1
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...  ...          5.7
# ...                                                  ...  ...          ...
# 45461             [{'iso_3166_1': 'IR', 'name': 'Iran'}]  ...          4.0
# 45462      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]  ...          9.0
# 45463  [{'iso_3166_1': 'US', 'name': 'United States o...  ...          3.8
# 45464           [{'iso_3166_1': 'RU', 'name': 'Russia'}]  ...          0.0
# 45465   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]  ...          0.0
#
#        vote_count     genre1   genre2    genre3  genre4  homePagePresent  \
# 0            5415  Animation   Comedy    Family                     True
# 1            2413  Adventure  Fantasy    Family                    False
# 2              92    Romance   Comedy                              False
# 3              34     Comedy    Drama   Romance                    False
# 4             173     Comedy                                       False
# ...           ...        ...      ...       ...     ...              ...
# 45461           1      Drama   Family                               True
# 45462           3      Drama                                       False
# 45463           6     Action    Drama  Thriller                    False
# 45464           0                                                  False
# 45465           0                                                  False
#
#       Producer1 Producer2 TotalLanguages
# 0                                      1
# 1                                      2
# 2                                      1
# 3                                      1
# 4                                      1
# ...         ...       ...            ...
# 45461                                  1
# 45462                                  1
# 45463                                  1
# 45464                                  0
# 45465                                  1
#
# [45403 rows x 25 columns]

# %%
dataBudgetRevenue  = data.loc[(data.budget != 0) & (data.revenue != 0),:]
dataBudgetRevenue
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5      False                                                NaN  60000000
# ...      ...                                                ...       ...
# 45399  False                                                NaN    750000
# 45401  False                                                NaN         0
# 45409  False                                                NaN    800000
# 45412  False                                                NaN   2000000
# 45422  False                                                NaN   5000000
#
#            id    imdb_id original_language               original_title  \
# 0         862  tt0114709                en                    toy story
# 1        8844  tt0113497                en                      jumanji
# 3       31357  tt0114885                en            waiting to exhale
# 4       11862  tt0113041                en  father of the bride part ii
# 5         949  tt0113277                en                         heat
# ...       ...        ...               ...                          ...
# 45399  280422  tt3805180                ru                  все и сразу
# 45401  240789  tt1197626                ru                         чудо
# 45409   62757  tt0933361                en                       dikari
# 45412   63281  tt1718881                en                   про любоff
# 45422   63898  tt1110037                ru                     антидурь
#
#                                                 overview  popularity  \
# 0      led by woody, andy's toys live happily in his ...   21.946943
# 1      when siblings judy and peter discover an encha...   17.015539
# 3      cheated on, mistreated and stepped on, the wom...    3.859495
# 4      just when george banks has recovered from his ...    8.387519
# 5      obsessive master thief, neil mccauley leads a ...   17.924927
# ...                                                  ...         ...
# 45399                                                NaN    0.201582
# 45401  the film is based on real events that took pla...    0.436028
# 45409  the sea, august, interesting and simple people...    0.903061
# 45412  у девушки даши, приехавшей с подругой «покорят...    0.121844
# 45422  failing to complete an important assignment wi...    0.039793
#
#                                     production_countries  ... vote_average  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...  ...          7.7
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...  ...          6.9
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...  ...          6.1
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...  ...          5.7
# 5      [{'iso_3166_1': 'US', 'name': 'United States o...  ...          7.7
# ...                                                  ...  ...          ...
# 45399           [{'iso_3166_1': 'RU', 'name': 'Russia'}]  ...          6.0
# 45401           [{'iso_3166_1': 'RU', 'name': 'Russia'}]  ...          6.3
# 45409                                                 []  ...          5.8
# 45412           [{'iso_3166_1': 'RU', 'name': 'Russia'}]  ...          4.0
# 45422           [{'iso_3166_1': 'RU', 'name': 'Russia'}]  ...          1.0
#
#        vote_count     genre1   genre2   genre3    genre4  homePagePresent  \
# 0            5415  Animation   Comedy   Family                       True
# 1            2413  Adventure  Fantasy   Family                      False
# 3              34     Comedy    Drama  Romance                      False
# 4             173     Comedy                                        False
# 5            1886     Action    Crime    Drama  Thriller            False
# ...           ...        ...      ...      ...       ...              ...
# 45399           4      Crime   Comedy                               False
# 45401           3      Drama  History  Mystery                      False
# 45409           6     Comedy    Drama                               False
# 45412           3    Romance    Drama                               False
# 45422           1     Action   Comedy    Crime   Foreign            False
#
#       Producer1 Producer2 TotalLanguages
# 0                                      1
# 1                                      2
# 3                                      1
# 4                                      1
# 5                                      2
# ...         ...       ...            ...
# 45399                                  1
# 45401                                  1
# 45409                                  1
# 45412                                  1
# 45422                                  1
#
# [7398 rows x 25 columns]
